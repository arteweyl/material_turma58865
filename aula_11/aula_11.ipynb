# %%
# %pip install matplotlib
# %pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 2, 30, 4, 5]
y = [10, 8, 6, 4, 2]

# %%
plt.plot(x,y)
plt.show()

# %%
x = ['estados unidos', 'Brasil', 'Canada', 'Dinamarca', 'Eslováquia']
população = [3, 7, 1, 8, 4]

plt.bar(x,y)
plt.show()

# %%
labels = ['Maçãs', 'Bananas', 'Laranjas', 'Morangos']
quantidades = [20, 25, 10, 30]
plt.pie(quantidades,labels=labels)
plt.show()

# %%
x = [15, 21, 30, 4, 5]
y = [100, 8, 6, 4, 25]
plt.scatter(x,y)
plt.show()

# %%
dados = [1, 3, 3, 4, 4, 4, 5, 5, 6, 7, 8, 9]
plt.hist(dados,bins=4)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.fill_between(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
posicao = [1, 2, 3, 4, 5]
velocidade = [2, 4, 6, 8, 10]

plt.plot(posicao,velocidade)

plt.title('função de velocidade em relação a posição')
plt.xlabel("Posição (m)")
plt.ylabel('Velocidade (m/s)')
# Out:
# Text(0, 0.5, 'Velocidade (m/s)')

# %%
posicao = [1, 2, 3, 4, 5]
velocidade = [2, 4, 6, 8, 10]

plt.plot(posicao,velocidade,
         color = 'orange',
         linestyle = '--',
         linewidth=2,
         marker = 'o',
         markersize = 10,
         markerfacecolor = 'blue'
         )

plt.title('função de velocidade em relação a posição')
plt.xlabel("Posição (m)")
plt.ylabel('Velocidade (m/s)')
plt.xlim(0,6)
plt.ylim(0,12)

plt.show()

# %%
t = np.linspace(0,10,100)
x = np.sin(t)
y = np.cos(t)
z = np.tan(t)

fig, axs = plt.subplots(3,1, figsize=(8, 10))
axs[0].plot(t,x)
axs[1].plot(t,y)
axs[2].plot(t,z)
plt.show()

# %%
import seaborn as sns

# %%
x = np.random.normal(size=100)

sns.displot(x,kde=True)
plt.show()

# %%
import pandas as pd

# %%
data = {'peso': [80, 65, 70, 60, 75, 66, 61, 73, 77],'altura': [180, 170, 175, 167, 172, 169, 166, 178, 169]}

df = pd.DataFrame(data)
df
# Out:
#    peso  altura
# 0    80     180
# 1    65     170
# 2    70     175
# 3    60     167
# 4    75     172
# 5    66     169
# 6    61     166
# 7    73     178
# 8    77     169

# %%
sns.scatterplot(x='peso',y='altura',data=df)
plt.show()

# %%
data = {'tipo': ['Venda', 'Venda', 'Compra', 'Compra', 'Venda', 'Compra'],
        'valor': [1000, 1500, 500, 800, 1200, 600]}

df2 = pd.DataFrame(data)

sns.boxplot(x='tipo',y='valor', data=df2)

plt.show()

# %% [markdown]
# ## gráfico de bolhas

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
plt.show()

# %% [markdown]
# ## gráfico com Multiplas funções

# %%
## forma orientada a objeto

x = np.linspace(0, 2, 100) # cojunto de dados


fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  
ax.plot(x, x**2, label='quadratico')  
ax.plot(x, x**3, label='cubico') 
ax.set_xlabel('Rotulo x')  
ax.set_ylabel('Rotulo Y') 
ax.set_title("MultiPlots")  
ax.legend()  # adiciona legenda no gráfico com vários plots
plt.show()

# %%
## forma orientada a estado

plt.plot(x, x, label='linear')  
plt.plot(x, x**2, label='quadratico')  
plt.plot(x, x**3, label='cubico') 
plt.xlabel('Rotulo x')  
plt.ylabel('Rotulo Y') 
plt.title("MultiPlots")  
plt.legend()  # adiciona legenda no gráfico com vários plots
plt.show()
